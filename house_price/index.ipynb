# %% [markdown]
# <a href="https://colab.research.google.com/github/kngan79/learn-data-science/blob/master/Handson_EDA_Ngan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # for scientific calculation
import pandas as pd # for spreadsheet
import matplotlib.pyplot as plt # for plotting
import seaborn as sns # for better plot
from scipy.stats import mode
# %matplotlib inline
# %load_ext google.colab.data_table
# Out:
# The google.colab.data_table extension is already loaded. To reload it, use:
#   %reload_ext google.colab.data_table

# %%
TRAIN_PATH = "https://raw.githubusercontent.com/tiwari91/Housing-Prices/master/train.csv"

# %% [markdown]
# # Data Loading
#
# In this tutorial, we use the function `read_csv` from Pandas library to load the csv file into the memory.

# %%
# Simple way
pd.read_csv(TRAIN_PATH)
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0        1          60       RL  ...        WD         Normal    208500
# 1        2          20       RL  ...        WD         Normal    181500
# 2        3          60       RL  ...        WD         Normal    223500
# 3        4          70       RL  ...        WD        Abnorml    140000
# 4        5          60       RL  ...        WD         Normal    250000
# ...    ...         ...      ...  ...       ...            ...       ...
# 1455  1456          60       RL  ...        WD         Normal    175000
# 1456  1457          20       RL  ...        WD         Normal    210000
# 1457  1458          70       RL  ...        WD         Normal    266500
# 1458  1459          20       RL  ...        WD         Normal    142125
# 1459  1460          20       RL  ...        WD         Normal    147500
#
# [1460 rows x 81 columns]

# %%
# Detailed way
house_price = pd.read_csv(TRAIN_PATH, sep = ",", header=0,
                          dtype={
                              "OverallQual":"int8",
                              "OverallCond":"int8"
                          })

# %%
# Print some first rows
house_price.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
house_price.loc[0:10,['Id','LotArea']]
# Out:
#     Id  LotArea
# 0    1     8450
# 1    2     9600
# 2    3    11250
# 3    4     9550
# 4    5    14260
# 5    6    14115
# 6    7    10084
# 7    8    10382
# 8    9     6120
# 9   10     7420
# 10  11    11200

# %%
col = ['A','B','C']
lower_col = [name.lower() for name in col]
print(lower_col)
# Out:
# ['a', 'b', 'c']

# %%
lower_names = [name.lower() for name in house_price.columns]
print(lower_names)
# Out:
# ['id', 'mssubclass', 'mszoning', 'lotfrontage', 'lotarea', 'street', 'alley', 'lotshape', 'landcontour', 'utilities', 'lotconfig', 'landslope', 'neighborhood', 'condition1', 'condition2', 'bldgtype', 'housestyle', 'overallqual', 'overallcond', 'yearbuilt', 'yearremodadd', 'roofstyle', 'roofmatl', 'exterior1st', 'exterior2nd', 'masvnrtype', 'masvnrarea', 'exterqual', 'extercond', 'foundation', 'bsmtqual', 'bsmtcond', 'bsmtexposure', 'bsmtfintype1', 'bsmtfinsf1', 'bsmtfintype2', 'bsmtfinsf2', 'bsmtunfsf', 'totalbsmtsf', 'heating', 'heatingqc', 'centralair', 'electrical', '1stflrsf', '2ndflrsf', 'lowqualfinsf', 'grlivarea', 'bsmtfullbath', 'bsmthalfbath', 'fullbath', 'halfbath', 'bedroomabvgr', 'kitchenabvgr', 'kitchenqual', 'totrmsabvgrd', 'functional', 'fireplaces', 'fireplacequ', 'garagetype', 'garageyrblt', 'garagefinish', 'garagecars', 'garagearea', 'garagequal', 'garagecond', 'paveddrive', 'wooddecksf', 'openporchsf', 'enclosedporch', '3ssnporch', 'screenporch', 'poolarea', 'poolq
# ...

# %%
house_price.columns = lower_names
house_price.head()
# Out:
#    id  mssubclass mszoning  ...  saletype  salecondition saleprice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %% [markdown]
# # Data Exploratory

# %% [markdown]
# ## Overview

# %%
# Data shape / Data dimension
house_price.shape
# Out:
# (1460, 81)

# %%
# Data type & Memory
house_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# Numerical vs Non-numerical
numerical_data = house_price.select_dtypes("number").columns
non_numerical_data = house_price.select_dtypes("object").columns

# %%
house_price[non_numerical_data]
# Out:
#      MSZoning Street Alley LotShape  ...  Fence MiscFeature SaleType SaleCondition
# 0          RL   Pave   NaN      Reg  ...    NaN         NaN       WD        Normal
# 1          RL   Pave   NaN      Reg  ...    NaN         NaN       WD        Normal
# 2          RL   Pave   NaN      IR1  ...    NaN         NaN       WD        Normal
# 3          RL   Pave   NaN      IR1  ...    NaN         NaN       WD       Abnorml
# 4          RL   Pave   NaN      IR1  ...    NaN         NaN       WD        Normal
# ...       ...    ...   ...      ...  ...    ...         ...      ...           ...
# 1455       RL   Pave   NaN      Reg  ...    NaN         NaN       WD        Normal
# 1456       RL   Pave   NaN      Reg  ...  MnPrv         NaN       WD        Normal
# 1457       RL   Pave   NaN      Reg  ...  GdPrv        Shed       WD        Normal
# 1458       RL   Pave   NaN      Reg  ...    NaN         NaN       WD        Normal
# ...

# %%
# Basic statistics
house_price.describe()
# Out:
#                 Id   MSSubClass  ...       YrSold      SalePrice
# count  1460.000000  1460.000000  ...  1460.000000    1460.000000
# mean    730.500000    56.897260  ...  2007.815753  180921.195890
# std     421.610009    42.300571  ...     1.328095   79442.502883
# min       1.000000    20.000000  ...  2006.000000   34900.000000
# 25%     365.750000    20.000000  ...  2007.000000  129975.000000
# 50%     730.500000    50.000000  ...  2008.000000  163000.000000
# 75%    1095.250000    70.000000  ...  2009.000000  214000.000000
# max    1460.000000   190.000000  ...  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
(house_price == 0).sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
pd.isnull(house_price).sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
# Custom data dictionary
def generate_data_dict(house_price):
  mean = house_price.mean()
  median = house_price.median()
 # mode_value, mode_count = mode(house_price)
  std = house_price.std()
  count_distinct = house_price.nunique()
  n_missing = pd.isnull(house_price).sum()
  n_zeroes = (house_price == 0).sum()

  results = {
      "mean": mean,
      "median": median,
      #"mode": mode_value[0],
      "std": std,
      "count_distinct": count_distinct,
      "n_zeroes": n_zeroes
  }
 
  res_df = pd.DataFrame(results)
  return res_df

# %%
generate_data_dict(house_price)
# Out:
#                      mean  median         std  count_distinct  n_zeroes
# 1stFlrSF      1162.626712  1087.0  386.587738             753         0
# 2ndFlrSF       346.992466     0.0  436.528436             417       829
# 3SsnPorch        3.409589     0.0   29.317331              20      1436
# Alley                 NaN     NaN         NaN               3         0
# BedroomAbvGr     2.866438     3.0    0.815778               8         6
# ...                   ...     ...         ...             ...       ...
# Utilities             NaN     NaN         NaN               2         0
# WoodDeckSF      94.244521     0.0  125.338794             274       761
# YearBuilt     1971.267808  1973.0   30.202904             112         0
# YearRemodAdd  1984.865753  1994.0   20.645407              61         0
# YrSold        2007.815753  2008.0    1.328095               5         0
#
# [81 rows x 5 columns]

# %% [markdown]
# ## Data Cleaning
#
# * Missing values
# * Outliers handling

# %% [markdown]
# ### Missing values

# %%
# Simple way
house_price = house_price.fillna(-1)

# %%
# Detailed way
## Numerical data
house_price[numerical_data]= house_price[numerical_data].fillna("mean")
## Non-numerical data
house_price[non_numerical_data]= house_price[non_numerical_data].fillna("mode")

# %%
generate_data_dict(house_price)
# Out:
#                      mean  median         std  count_distinct  n_zeroes
# 1stFlrSF      1162.626712  1087.0  386.587738             753         0
# 2ndFlrSF       346.992466     0.0  436.528436             417       829
# 3SsnPorch        3.409589     0.0   29.317331              20      1436
# Alley                 NaN     NaN         NaN               3         0
# BedroomAbvGr     2.866438     3.0    0.815778               8         6
# ...                   ...     ...         ...             ...       ...
# Utilities             NaN     NaN         NaN               2         0
# WoodDeckSF      94.244521     0.0  125.338794             274       761
# YearBuilt     1971.267808  1973.0   30.202904             112         0
# YearRemodAdd  1984.865753  1994.0   20.645407              61         0
# YrSold        2007.815753  2008.0    1.328095               5         0
#
# [81 rows x 5 columns]

# %%
# Recheck the missing counts

# %% [markdown]
# ### Outliers

# %%
# Histogram
house_price['SalePrice'].hist(bins=30)

# %%
# Z score
from scipy.stats import zscore

# %%
z_saleprice = zscore(house_price.SalePrice)

# %%
plt.hist(z_saleprice, bins=30)
# Out:
# (array([ 11.,  38.,  99., 232., 273., 218., 176., 104.,  93.,  58.,  42.,
#          35.,  24.,  10.,  17.,   8.,   7.,   4.,   2.,   1.,   1.,   2.,
#           1.,   0.,   2.,   0.,   0.,   0.,   0.,   2.]),
#  array([-1.83870376, -1.53645299, -1.23420222, -0.93195144, -0.62970067,
#         -0.3274499 , -0.02519913,  0.27705165,  0.57930242,  0.88155319,
#          1.18380397,  1.48605474,  1.78830551,  2.09055628,  2.39280706,
#          2.69505783,  2.9973086 ,  3.29955937,  3.60181015,  3.90406092,
#          4.20631169,  4.50856246,  4.81081324,  5.11306401,  5.41531478,
#          5.71756556,  6.01981633,  6.3220671 ,  6.62431787,  6.92656865,
#          7.22881942]),
#  <a list of 30 Patch objects>)

# %%
z_gt_2 = np.abs(z_saleprice) > 2
z_gt_2
# Out:
# array([False, False, False, ..., False, False, False])

# %%
house_price.loc[z_gt_2]
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 11      12          60       RL  ...       New        Partial    345000
# 53      54          20       RL  ...        WD         Normal    385000
# 58      59          60       RL  ...       New        Partial    438780
# 112    113          60       RL  ...       New        Partial    383970
# 151    152          20       RL  ...       New        Partial    372402
# ...    ...         ...      ...  ...       ...            ...       ...
# 1353  1354          50       RL  ...        WD         Normal    410000
# 1373  1374          20       RL  ...        WD         Normal    466500
# 1388  1389          20       RL  ...        WD         Normal    377500
# 1417  1418          60       RL  ...        WD         Normal    340000
# 1437  1438          20       RL  ...       New        Partial    394617
#
# [63 rows x 81 columns]

# %%
outlier_row = house_price.loc[z_gt_2].index

# %%
house_price = house_price.drop(index=outlier_row)

# %%
house_price.shape
# Out:
# (1397, 81)

# %% [markdown]
# # Exploratory analysis

# %%
# Scatter plot OverallQual vs SalePrice
## matplotlib
plt.scatter(x=house_price.OverallQual,y=house_price.SalePrice)

# %%
## seaborn
sns.catplot(x="OverallQual",y="SalePrice", data=house_price,kind='box')

# %%
plt.scatter(np.log(house_price.LotArea), np.log(house_price.SalePrice))

# %%
# Correlation coefficient
## Correlation matrix
corr_mat = house_price.corr()

# %%
## Correlation heatmap
sns.heatmap(corr_mat)

# %% [markdown]
# # Feature engineering

# %%
# YearBuilt to YearOld
house_price['YearOld'] = 2020 - house_price['YearBuilt']

# %%
house_price.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleCondition  SalePrice YearOld
# 0   1          60       RL  ...         Normal     208500      17
# 1   2          20       RL  ...         Normal     181500      44
# 2   3          60       RL  ...         Normal     223500      19
# 3   4          70       RL  ...        Abnorml     140000     105
# 4   5          60       RL  ...         Normal     250000      20
#
# [5 rows x 82 columns]

# %%
# Categorical -> One-hot encoding
house_price = pd.get_dummies(house_price)
